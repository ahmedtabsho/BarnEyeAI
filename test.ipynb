# %%
print("Hello world")
# Out:
# Hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veriler
confusion_matrix = np.array([[56, 0, 0, 9],
                             [0, 630, 0, 50],
                             [0, 0, 11065, 502],
                             [9, 23, 272, 0]])

# Grafiği çizme
plt.figure(figsize=(8, 6))
plt.imshow(confusion_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Eksen etiketleri
classes = ['Chicken', 'Cow', 'Sheep', 'Background']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

# Değerlerin ekleme
thresh = confusion_matrix.max() / 2.
for i in range(confusion_matrix.shape[0]):
    for j in range(confusion_matrix.shape[1]):
        plt.text(j, i, format(confusion_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Grafiği gösterme veya kaydetme
plt.savefig('confusion_matrix.png')  # Fotoğraf olarak kaydetmek için
plt.show()  # Grafiği göstermek için

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the images
path1 = '/home/ahmedtab/Desktop/Final_Porject/detected_chickens.jpg'
path2 = '/home/ahmedtab/Desktop/Final_Porject/detected_cows.jpg'
path3 = '/home/ahmedtab/Desktop/Final_Porject/detected_sheeps.jpg'

# Load the images
img1 = mpimg.imread(path1)
img2 = mpimg.imread(path2)
img3 = mpimg.imread(path3)

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Show images
axes[0].imshow(img1)
axes[0].set_title('Chickens')
axes[0].axis('off')

axes[1].imshow(img2)
axes[1].set_title('Cows')
axes[1].axis('off')

axes[2].imshow(img3)
axes[2].set_title('Sheeps')
axes[2].axis('off')

# Adjust layout
plt.tight_layout()
plt.show()
